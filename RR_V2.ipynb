# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib_venn import venn2
import warnings
warnings.filterwarnings('ignore')

# %%
data= pd.read_excel('/Users/parvezshahshaik/Documents/Github/restaurant_recommendation/restaurent_data/data.xlsx')

# %% [markdown]
# ## Prelimary Data Inspection

# %%
data.head(500)
# Out:
#      Restaurant ID                                    Restaurant Name  \
# 0          7402935                                               Skye
# 1          7410290                           Satoo - Hotel Shangri-La
# 2          7420899                                         Sushi Masa
# 3          7421967                                     3 Wise Monkeys
# 4          7422489                        Avec Moi Restaurant and Bar
# 5         18352452                         Lucky Cat Coffee & Kitchen
# 6         18386856                                            Onokabe
# 7          7423482                                         Lemongrass
# 8         18391256                                              MONKS
# 9          7422633                                   Talaga Sampireun
# 10        18425821                                               OJJU
# 11         7422751                                         Union Deli
# 12         7400818                                              Zenbu
# 13         7417455                                   Talaga Sampireun
# 14         7417450                                   Talaga Sampireun
# 15         7405789                                        Toodz House
# 16        18400530                             Noah's Barn Coffeenery
# 17        18370659                                        Flip Burger
# 18        18409146                                        Fish Streat
# 19        18408381                                        Fish Streat
# 20         7423620                                          Momo Milk
# 21            2701                  Orient Express - Taj Palace Hotel
# 22          309548           Tian - Asian Cuisine Studio - ITC Maurya
# 23            2742                               Bukhara - ITC Maurya
# 24         6300010           Spiral - Sofitel Philippine Plaza Manila
# 25          301523         Nostalgia at 1911 Brasserie - The Imperial
# 26            2724                                1911 - The Imperial
# 27            2725                     The Spice Route - The Imperial
# 28            2694           Wasabi by Morimoto - The Taj Mahal Hotel
# 29            6812                            MEGU - The Leela Palace
# 30            2689                House of Ming - The Taj Mahal Hotel
# 31            3910              24/7 Restaurant - The Lalit New Delhi
# 32            2443                            Wildfire - Crowne Plaza
# 33        18255131                                            Privee'
# 34        18345728                                     Masala Library
# 35            3246                         Le Belvedere - Le Meridien
# 36        18277024             Shang Palace - Shangri-La's Eros Hotel
# 37        18261160               Sorrento - Shangri-La's - Eros Hotel
# 38            2681                               Jade - The Claridges
# 39            2727                       San Gimignano - The Imperial
# 40            4907                     Kitty Su - The Lalit New Delhi
# 41            4910                       Le Cirque - The Leela Palace
# 42            4496               The Grill Room - The Taj Mahal Hotel
# 43            2690                       Machan - The Taj Mahal Hotel
# 44          305548                      Empress of China - Eros Hotel
# 45        18268390                                               Hype
# 46          307416                      I-Kandy - Le Meridien Gurgaon
# 47            3379                          La Piazza - Hyatt Regency
# 48            3378                      China Kitchen - Hyatt Regency
# 49          306251                   Oval Bar - JW Marriott New Delhi
# 50            3937                              The One - Le Meridien
# 51            3235                       Eau De Monsoon - Le Meridien
# 52            2675                            Sevilla - The Claridges
# 53          309110               The Grill Room - The Lalit New Delhi
# 54            3027                      Baluchi - The Lalit New Delhi
# 55             104                         Woks - The Lalit New Delhi
# 56            2769                                    Aqua - The Park
# 57            2693                         Varq - The Taj Mahal Hotel
# 58         5800710                          The Manhattan Fish Market
# 59          312902                     Club BW - The Suryaa New Delhi
# 60            2682                              Dhaba - The Claridges
# 61            3948                    Ricks Bar - The Taj Mahal Hotel
# 62            2683                               Aura - The Claridges
# 63         6300002                             Heat - Edsa Shangri-La
# 64        18369743                 Bella Cucina - Le Meridien Gurgaon
# 65          301562                     Thai Pavilion - Vivanta By Taj
# 66          305545                                Blooms - Eros Hotel
# 67            2004                          Indian Accent - The Manor
# 68            4366                    Jasmine - Hotel The Royal Plaza
# 69            4356               T.K'S Oriental Grill - Hyatt Regency
# 70            2739                 Dakshin - Sheraton New Delhi Hotel
# 71            2728                    Daniell's Tavern - The Imperial
# 72            4917                         Jamavar - The Leela Palace
# 73        18376469                      Spicy Duck - Taj Palace Hotel
# 74         5800746                                    T.G.I. Friday's
# 75         5800176                                   Ministry of Crab
# 76          311369                  Tamra - Shangri-La's - Eros Hotel
# 77        18425766                        Chidya Ghar - Roseate House
# 78            1900                               The Oudh - The Ashok
# 79          305549                          Lounge & Bar - Eros Hotel
# 80         3400072                       Dawat-e-Nawab - Radisson Blu
# 81            1898                               Frontier - The Ashok
# 82            2674                          Pickwicks - The Claridges
# 83            4358                              Cafe G - Crowne Plaza
# 84          301559                          Latitude - Vivanta By Taj
# 85          304239                              FIO Cookhouse and Bar
# 86            4357                               Cafe - Hyatt Regency
# 87            2745                              Golf Bar - ITC Maurya
# 88            4503                          Paatra - Jaypee Siddharth
# 89        18261157                 Grappa - Shangri-La's - Eros Hotel
# 90          300696      Mei Kun - The Leela Ambience Convention Hotel
# 91          300695     Dilli 32 - The Leela Ambience Convention Hotel
# 92            4911                     The Library - The Leela Palace
# 93            2770                                    Mist - The Park
# 94            8351                             Paatra - Jaypee Greens
# 95         5800758                                         Cafe Shaze
# 96        18422475                                              Nagai
# 97            4283                        FIO Country Kitchen and Bar
# 98           75989                     Restaurant Mosaic @ The Orient
# 99            8241                                 7 Degrees Brauhaus
# 100           4374                    The Curzon Room - Maidens Hotel
# 101         301422                        Larry's China - Taj Vivanta
# 102           4840                     Cascades - The Grand New Delhi
# 103           3924                                S-18 - Radisson Blu
# 104        6315438                                     NIU by Vikings
# 105       18361778                   Ninkasi Imperial Brews & Cookery
# 106           7516              The Food Store - DoubleTree by Hilton
# 107           5720                 New Town Lounge & Bar - Park Plaza
# 108           7573               The Great Kabab Factory - Park Plaza
# 109           5717                          Cigar Lounge - The Oberoi
# 110           5042                          EEST - The Westin Gurgaon
# 111           5044                         Prego - The Westin Gurgaon
# 112           5046               Seasonal Tastes - The Westin Gurgaon
# 113         310700           Xiao Chi - The Westin Sohna Resort & Spa
# 114         310699    The Living Room - The Westin Sohna Resort & Spa
# 115           2710                           Konomi - Trident Gurgaon
# 116        2300187                     Waterside - The Landmark Hotel
# 117       18466422                                       Playboy Club
# 118       18264992                        Lakhori - Haveli Dharampura
# 119         307361                            Infinity - Crowne Plaza
# 120         307801                            Artusi Ristorante e Bar
# 121           4367                   Lutyen's - Hotel The Royal Plaza
# 122       18372578                                               RSVP
# 123           4502                   Eggspectation - Jaypee Siddharth
# 124           4235                  Tapas - Jaypee Vasant Continental
# 125           4234          Eggspectation - Jaypee Vasant Continental
# 126           6600                                 Nero - Le Meridien
# 127           4373                 The Garden Terrace - Maidens Hotel
# 128       18415386                     Aqua Grill - Pride Plaza Hotel
# 129         302282               Neung Roi - Radisson Blu Plaza Delhi
# 130           3545                     NYC - Radisson Blu Plaza Delhi
# 131           3547  The Great Kabab Factory - Radisson Blu Plaza D...
# 132       18382353                                DEL - Roseate House
# 133           4889                    India Grill - Hilton Garden Inn
# 134       18133508          Delhi Pavilion - Sheraton New Delhi Hotel
# 135           2741               Pan Asian - Sheraton New Delhi Hotel
# 136           3239                             Insomnia - Taj Vivanta
# 137           2729                         Patiala Peg - The Imperial
# 138         301524                      24/7 Bar- The Lalit New Delhi
# 139           3283                                   Elan - The Lodhi
# 140           2768                                    Agni - The Park
# 141           3202        Atrium Bar  & Lounge - The Suryaa New Delhi
# 142           9709                                Bonitos - The Uppal
# 143        5800316                                  Cricket Club Cafe
# 144        5800433                                         The Sizzle
# 145         304931                                              Guppy
# 146           5608                                  SSKY Bar & Lounge
# 147           1669                         New Town Cafe - Park Plaza
# 148       18441709     Downtown Kitchen & Bar - Courtyard by Marriott
# 149       18469938                                                BED
# 150         300688  CafÌ© Knosh - The Leela Ambience Convention Hotel
# 151           3227                         GBar - The Grand New Delhi
# 152         300697   Cherry Bar - The Leela Ambience Convention Hotel
# 153           1188                       Lodi - The Garden Restaurant
# 154           3695                                         Geoffrey's
# 155        3400059                              Peshawri - ITC Mughal
# 156        3400060                              Taj Bano - ITC Mughal
# 157         300713                                      9 Mars Lounge
# 158           5876                          Lattitude - Skycity Hotel
# 159       18441707            Courtyard Grill - Courtyard by Marriott
# 160         306133                           California Pizza Kitchen
# 161         305905                                     Hard Rock Cafe
# 162       18255106                             Uptown Fresh Beer Cafe
# 163         305400                     Orchid - Fortune Select Global
# 164           3855                                           L'Angoor
# 165           1245                                       TGI Friday's
# 166           3575                                    Gung The Palace
# 167       18306533                                      The Brewhouse
# 168           3961                        Palmyra - The Bristol Hotel
# 169       18291211                            Zaffran - The Claremont
# 170           7496                        Melange - The Pllazio Hotel
# 171       18291200                                          Town Hall
# 172       18291198                                       Whisky Samba
# 173         102216  Chao Chinese Bistro - Holiday Inn Jaipur City ...
# 174           3295                                Restaurant De Seoul
# 175           5997                      Connexions Bar - Crowne Plaza
# 176           3719                                       TGI Friday's
# 177       18294261                           Lord of the Drinks Forum
# 178             64                      Diva - The Italian Restaurant
# 179           3400                                    Gung The Palace
# 180           1267                    Yellow Mirchi - Hotel City Park
# 181           4364                   Onyx Bar - Hotel The Royal Plaza
# 182         310365     SKY Lounge Bar & Grill - Hotel The Royal Plaza
# 183           4365    Lord William Tea Lounge - Hotel The Royal Plaza
# 184           3264                        Polo Lounge - Hyatt Regency
# 185           8521                           Mosaic - SK Premium Park
# 186           4499                Ano Tai - Jaypee Vasant Continental
# 187           4501                 Paatra - Jaypee Vasant Continental
# 188         310674                                   Cafe Illuminatii
# 189         307802                                          Town Hall
# 190       18265677                                           The Krib
# 191         310348                                   Admission Lounge
# 192       18408062                       Stallion - Pride Plaza Hotel
# 193           3549            Savannah Bar - Radisson Blu Plaza Delhi
# 194           4488                         Oro The Bar - Radisson Blu
# 195       18463567                                              Nueva
# 196         309852                                        Club London
# 197           4404                    Yellow Brick Road - Taj Vivanta
# 198         306198                                Zerruco - The Ashok
# 199           2731                          The Atrium - The Imperial
# 200           5325                      Sampan - The Suryaa New Delhi
# 201           2688             Emperor's Lounge - The Taj Mahal Hotel
# 202         312319                            Bonitos Blu - The Uppal
# 203       18282047                Arriba - Mexican Grill & Tequileria
# 204           3212                                            Chicane
# 205           1244                                       TGI Friday's
# 206        5800567                                    CIOCONAT Lounge
# 207        5800590                                        The Commons
# 208        5800755                                            Upali's
# 209          58268                   The Fatty Bao - Asian Gastro Bar
# 210           3288          Shanghai Bar & Lounge - The Bristol Hotel
# 211            929                                      Pebble Street
# 212           3393               Parikrama - The Revolving Restaurant
# 213         307330                               Moonshine Cafe & Bar
# 214       18359296                                             Liquid
# 215           3237                                      Club Ice Cube
# 216        5801078                                    Arabian Knights
# 217       18175334                             TFK - The Flaming Kick
# 218         308016                                    Sutra Gastropub
# 219         102215  Monarch Restaurant - Holiday Inn Jaipur City C...
# 220         306581                                  The Hungry Monkey
# 221         121120                                   Virgin Courtyard
# 222       18306521                Big Shot Bar - Country Inn & Suites
# 223         308022                                         Farzi Cafe
# 224           2148                             56 Ristorante Italiano
# 225         312668                                 SBar Club & Lounge
# 226           1670                         New Town Cafe - Park Plaza
# 227       18434414                                    Fashion Tv Cafe
# 228           4905                                       Kylin Skybar
# 229         312603                                 Lord of the Drinks
# 230       18233593                                         Farzi Cafe
# 231            910                                United Coffee House
# 232           3620                                          Cafe Diva
# 233           4821                                        Uber Lounge
# 234       18408040                          Lord of the Drinks Meadow
# 235       17977751                                           The Nest
# 236       18255171                                    Tokyo Mon Amour
# 237           4341                            The Great Kabab Factory
# 238           5448                               The 87 - Premier Inn
# 239       18294265                         Lord of the Drinks Chamber
# 240           3298                                           Voda Bar
# 241           3403                                      Basil & Thyme
# 242       18264963                                           Number 8
# 243           3955                                Samavar - The Ashok
# 244         311305                                              Tribe
# 245       18317498              The Butler & The Chef - Jaypee Greens
# 246           3226                             Flluid - Mosaic Hotels
# 247           4248                            The Great Kabab Factory
# 248       17977757               Coffee to Cocktail Bar - Hyatt Place
# 249       18252386                                 BRONX Bar Exchange
# 250         308579                                The Town House Cafe
# 251       18466978                    Gatsby Kitchen & Bar by Club BW
# 252         311982                             Lutyens Cocktail House
# 253       18255125                                      Public Affair
# 254         313207                             Smokey's BBQ and Grill
# 255       18277165                                Ping's CafÌ© Orient
# 256           4752                                      Lighthouse 13
# 257        6506206                            18 Degrees Resto Lounge
# 258        6300781                                         Buffet 101
# 259        6301290                                            Vikings
# 260        3400325                                          MoMo Cafe
# 261          51705                                               Toit
# 262          65055                                    Barbeque Nation
# 263         130332                                        Club Cubana
# 264       18022206                                            Antares
# 265           2787                                       Punjab Grill
# 266         306956                                       Olive Bistro
# 267         307309                                             Raasta
# 268         306134                                   The Wine Company
# 269         306946                                 Cafe Delhi Heights
# 270         306153                                 Dhaba By Claridges
# 271         310737                                  7 Barrel Brew Pub
# 272           7518        Spiritual Bar & Lounge-DoubleTree by Hilton
# 273         311805                                          Club Mojo
# 274           4719       India on my Plate - Fortune Select Excalibur
# 275         303960                   Manhattan Brewery & Bar Exchange
# 276         307580                                           Side Wok
# 277       18441771                                            The Ark
# 278           6700                   Citrus Cafe - Lemon Tree Premier
# 279            997                                         China Club
# 280           8913                                   Pirates of Grill
# 281           3243                                      K2 Restaurant
# 282           4398                                      21 Gun Salute
# 283       18446415                          The Old School Brew House
# 284         301499                                         Bernardo's
# 285           7231                        Zaffran - The Bristol Hotel
# 286           2711                          The Bar - Trident Gurgaon
# 287           6690                     Citrus Cafe - Lemon Tree Hotel
# 288          93766                                       Olive Bistro
# 289        1400169          The Creative Kitchen - Radisson Blu Hotel
# 290       18209498                      Zolocrust - Hotel Clarks Amer
# 291         801384                   L 14 - Renaissance Lucknow Hotel
# 292          15705                      Kitchen At 95 - Hyatt Regency
# 293            819                                       Lotus Garden
# 294           3089                                Etal The Lounge Bar
# 295             66                                            Embassy
# 296           7713                                          Ardor 2.1
# 297         306913                                            Caffe 9
# 298         310123                           Fuji Japanese Restaurant
# 299         307362                        Lobby Lounge - Crowne Plaza
# 300            760                                        Moets Stone
# 301           9969                                     Qash Retro Bar
# 302       18237320                                 The Cocktail House
# 303         300007                                           Side Wok
# 304       18203180                                  The Laidback Cafe
# 305       18241869                                             Tashan
# 306       18462002                                              Baris
# 307           8893                                             Raasta
# 308         306510                            Cafe on 3 - Holiday Inn
# 309            422                      Chor Bizarre - Hotel Broadway
# 310           3260                        Opium Bar - Hotel City Park
# 311       18419892                               Royal Brewery Bistro
# 312         306026               Ira - The Waterside Bar - ITC Maurya
# 313           6174                             Gulnar - Hotel Janpath
# 314       18357911                                    Tourist Janpath
# 315           3541                                            Zaffran
# 316           4741                                       Boombox Cafe
# 317           3425                                        Latitude 28
# 318         305686                                           Side Wok
# 319         307799                                 Wok  In The Clouds
# 320       18221038                                           Parallel
# 321         313299                            Perch Wine & Coffee Bar
# 322           3943                          Henri's Bar - Le Meridien
# 323           4380                            Longitude - Le Meridien
# 324         303753                                   Elma's Brasserie
# 325         311470                                        Diva Spiced
# 326           3286                    The Cavalry Bar - Maidens Hotel
# 327           9736                        The Epicure - Fraser Suites
# 328           3207                                               Buzz
# 329       18317481                               Aces - The Card Room
# 330       18317479                       London Eye - The Open Lounge
# 331       18317476                         Lord's - The Sports Lounge
# 332           4568                                  Spaghetti Kitchen
# 333         307501                             Zune - Piccadily Hotel
# 334           5446                                 Linx - Premier Inn
# 335           4490                           Cup Cakes - Radisson Blu
# 336         304746                           The California Boulevard
# 337       18472653                   Marine Drivve - Club & Courtyard
# 338         310167                                           Sufiaana
# 339       18237319                                        Dirty Apron
# 340       18124378                                          Cafe Diva
# 341       18126111                                 Cafe Delhi Heights
# 342       18429148                                           Pa Pa Ya
# 343       18424903                                    Andrea's Eatery
# 344       18219539            Mister Chai - Shangri-La's - Eros Hotel
# 345       18427201                                          F Marquee
# 346       18312443                The Claridges Garden -The Claridges
# 347           2726                            1911 Bar - The Imperial
# 348           4915                The Lobby Lounge - The Leela Palace
# 349       18400770                 Capital Kitchen - Taj Palace Hotel
# 350       18289247                            Perch Wine & Coffee Bar
# 351            718                          Americana Kitchen and Bar
# 352           2655                 Fortune Deli -  Fortune Inn Grazia
# 353       18279442                                  The Smoke Factory
# 354         301461                                           Airborne
# 355           8344                             Matrix - Jaypee Greens
# 356       18430587                                        Malt n Brew
# 357           6036                       New Town Lounge - Park Plaza
# 358            166                                  Punjabi By Nature
# 359           4717                                    RPM - Zanzi Bar
# 360           1733                                 Eden Kitchen & Bar
# 361         120519                                      Hops n Grains
# 362       18378852                                  Effingut Brewerkz
# 363        2700032                          Waterfront - Radisson Blu
# 364        5800557                                Chinese Dragon Cafe
# 365        5800891                                     The Paddington
# 366        5800156                                       Queen's Cafe
# 367        5801321                                       Cafe Beverly
# 368        1402314                            Hobnob Gourmet CafÌ©bar
# 369           2786                                       Punjab Grill
# 370           8417           World Cafe - Vibe by The LaLiT Traveller
# 371         307533                             Bar Code - Leisure Inn
# 372          96626  Jonathan's Kitchen - Holiday Inn Express & Suites
# 373          24286                                    The Irish House
# 374       18279449                                            HotMess
# 375           8881                                           G Lounge
# 376         307065                         Sakley's The Mountain Cafe
# 377         306264                                            Kabooze
# 378       18462572                                          Paparazzi
# 379           8369                                        Garage Inc.
# 380           5732                    Elma's Bakery, Bar, and Kitchen
# 381           3782                                           Fresc Co
# 382         307415                                          Urban Hub
# 383           1185                          Americana Kitchen and Bar
# 384       18198459                      World Art Dining - Brew House
# 385       18279455               Turquoise Cottage - TC Original 1997
# 386           5032                               Power Play Resto Bar
# 387       18025114                                Bottles and Barrels
# 388         307490                                  Summer House Cafe
# 389        6310406                      The Food Hall by Todd English
# 390         110502                  Patang - The Revolving Restaurant
# 391        2500024  Madhuban Restaurant - Welcome Hotel Rama Inter...
# 392          58882                                        Big Brewsky
# 393        2600303                         Kebabsville - Sayaji Hotel
# 394         123125                                       TGI Friday's
# 395         300488           Mosaic - Country Inn & Suites by Carlson
# 396       18277179                                        Yum Yum Cha
# 397         308357                                         Holy Smoke
# 398       18337929                                Indigo Delicatessen
# 399         302455                                     Mediumwelldone
# 400           5230                           Ion Club & Dining Lounge
# 401           3585                              Suburbia - The Empire
# 402       18391155                                     Hahn's Kitchen
# 403           3953                                        Club Prison
# 404         300772                                     Mainland China
# 405         310203                         Sandys Cocktails & Kitchen
# 406           4959               Downtown - Diners & Living Beer Cafe
# 407           7528                                  Indian Grill Room
# 408          97824                                            Chili's
# 409          90847                                            Chili's
# 410          92577                                   Heart Cup Coffee
# 411         100305                         The Forresta Kitchen & Bar
# 412          25587                                       TGI Friday's
# 413       18441775                                      Jom Jom Malay
# 414       18232098                                   Mystique Melange
# 415           3269                                                RPM
# 416             53                                              Amber
# 417       18357940                           Zabardast Indian Kitchen
# 418         308804                                       China Garden
# 419           3394                                            Zaffran
# 420         309478                                     Ambrosia Bliss
# 421         307036                                     Excuse Me Boss
# 422         309859                                      Pebble Street
# 423            570                                        Moets Shack
# 424       18254518                                The Jugaad Cafe Bar
# 425         307321                                             Habibi
# 426         305240                                  The Chatter House
# 427         305547                            Tea Lounge - Eros Hotel
# 428       18128883                       Yes Minister - Pub & Kitchen
# 429       18371438                                Thai House by Kylin
# 430       18363391                                            Depot48
# 431         310321                                           CDB Cafe
# 432         305125                                             Amalfi
# 433           1218                                       China Garden
# 434           1018                                     Mainland China
# 435             65                                    Drums of Heaven
# 436         301442                                         Imperfecto
# 437         308463                                            Maquina
# 438           5030                                     Out Of The Box
# 439         312801                 The Kylin Experience - Holiday Inn
# 440       18273615                                  The Chatter House
# 441         308195                                        Lahori Gate
# 442         311623                             Alcoholic Lounge & Bar
# 443            112                                         Lotus Pond
# 444       18057816                                            Asia 21
# 445       18082238                               The Submarine Lounge
# 446       18291260                                The Derby Cookhouse
# 447       18138443                            The Piano Man Jazz Club
# 448       18034053                                      The Fatty Bao
# 449           3921                                      Joy Luck Moon
# 450       18157416                                       Masala House
# 451       18272355                                   Pirates of Grill
# 452       18421057                                         Imperfecto
# 453           7784                                     Mainland China
# 454        6504409                                  Effingut Brewerkz
# 455          11371                                            Chili's
# 456        5800634                            Elite Indian Restaurant
# 457       18208920                                              Quaff
# 458         305269                                       Bonne Bouche
# 459         306505                                     2 Nice 2 Slice
# 460          73088                                            Chili's
# 461         304832                               Di Ghent Boulangerie
# 462         303858                                      The Pint Room
# 463         306132                                       Oh! Calcutta
# 464       18336176                                   The People & Co.
# 465           5960                         Escape Terrace Bar Kitchen
# 466       18430557                                           Takamaka
# 467       18285745                                   Delhi Club House
# 468        3600192                        Spring - Radisson Blu Plaza
# 469         303472                               The Kylin Experience
# 470         305453                              Chew - Pan Asian Cafe
# 471         312601                                    Open House Cafe
# 472         308244                Quote - The Eclectic Bar and Lounge
# 473       18161723                                             Ek Bar
# 474       18241531                                          Londoners
# 475       18222566                                       The Groghead
# 476       18222563                                          Bandstand
# 477         307360                                           Matchbox
# 478         307284                                 Harry's Bar + Cafe
# 479         308337                                          La Bodega
# 480           9618                                 The Blue Door Cafe
# 481       18419910                                        Civil House
# 482            803                                              Pindi
# 483       18222577                             CG's - Lounge Cafe Bar
# 484         309845                                         Grub House
# 485       18053052                                   Delhi Club House
# 486            131                                         Chopsticks
# 487         308007                                      The Pint Room
# 488           4627                           Latitude - Mosaic Hotels
# 489          11807                                    Barbeque Nation
# 490        2800052                         The Square - Hotel Novotel
# 491        2100861                      Underdoggs Sports Bar & Grill
# 492         101834                                           Blackout
# 493           3238                                               Ikko
# 494         312567                                          RoadRomeo
# 495       18413250                                        Fig & Maple
# 496         300656                                   Smoke House Deli
# 497         307620                                      Eleven Course
# 498         312482                                      Capital Grill
# 499         121552                                   Brooklyn Central
#
#      Country Code              City  \
# 0              94           Jakarta
# 1              94           Jakarta
# 2              94           Jakarta
# 3              94           Jakarta
# 4              94           Jakarta
# 5              94           Jakarta
# 6              94         Tangerang
# 7              94             Bogor
# 8              94           Jakarta
# 9              94           Jakarta
# 10             94           Jakarta
# 11             94           Jakarta
# 12             94           Jakarta
# 13             94           Jakarta
# 14             94         Tangerang
# 15             94           Jakarta
# 16             94           Bandung
# 17             94           Jakarta
# 18             94           Jakarta
# 19             94           Jakarta
# 20             94             Bogor
# 21              1         New Delhi
# 22              1         New Delhi
# 23              1         New Delhi
# 24            162        Pasay City
# 25              1         New Delhi
# 26              1         New Delhi
# 27              1         New Delhi
# 28              1         New Delhi
# 29              1         New Delhi
# 30              1         New Delhi
# 31              1         New Delhi
# 32              1           Gurgaon
# 33              1         New Delhi
# 34              1         New Delhi
# 35              1         New Delhi
# 36              1         New Delhi
# 37              1         New Delhi
# 38              1         New Delhi
# 39              1         New Delhi
# 40              1         New Delhi
# 41              1         New Delhi
# 42              1         New Delhi
# 43              1         New Delhi
# 44              1         New Delhi
# 45              1         New Delhi
# 46              1           Gurgaon
# 47              1         New Delhi
# 48              1         New Delhi
# 49              1         New Delhi
# 50              1         New Delhi
# 51              1         New Delhi
# 52              1         New Delhi
# 53              1         New Delhi
# 54              1         New Delhi
# 55              1         New Delhi
# 56              1         New Delhi
# 57              1         New Delhi
# 58            191           Colombo
# 59              1         New Delhi
# 60              1         New Delhi
# 61              1         New Delhi
# 62              1         New Delhi
# 63            162  Mandaluyong City
# 64              1           Gurgaon
# 65              1           Gurgaon
# 66              1         New Delhi
# 67              1         New Delhi
# 68              1         New Delhi
# 69              1         New Delhi
# 70              1         New Delhi
# 71              1         New Delhi
# 72              1         New Delhi
# 73              1         New Delhi
# 74            191           Colombo
# 75            191           Colombo
# 76              1         New Delhi
# 77              1         New Delhi
# 78              1         New Delhi
# 79              1         New Delhi
# 80              1              Agra
# 81              1         New Delhi
# 82              1         New Delhi
# 83              1           Gurgaon
# 84              1           Gurgaon
# 85              1         New Delhi
# 86              1         New Delhi
# 87              1         New Delhi
# 88              1         New Delhi
# 89              1         New Delhi
# 90              1         New Delhi
# 91              1         New Delhi
# 92              1         New Delhi
# 93              1         New Delhi
# 94              1             Noida
# 95            191           Colombo
# 96              1           Gurgaon
# 97              1         New Delhi
# 98            189          Pretoria
# 99              1           Gurgaon
# 100             1         New Delhi
# 101             1         New Delhi
# 102             1         New Delhi
# 103             1             Noida
# 104           162       Taguig City
# 105             1           Gurgaon
# 106             1           Gurgaon
# 107             1           Gurgaon
# 108             1           Gurgaon
# 109             1           Gurgaon
# 110             1           Gurgaon
# 111             1           Gurgaon
# 112             1           Gurgaon
# 113             1           Gurgaon
# 114             1           Gurgaon
# 115             1           Gurgaon
# 116             1            Kanpur
# 117             1         New Delhi
# 118             1         New Delhi
# 119             1         New Delhi
# 120             1         New Delhi
# 121             1         New Delhi
# 122             1         New Delhi
# 123             1         New Delhi
# 124             1         New Delhi
# 125             1         New Delhi
# 126             1         New Delhi
# 127             1         New Delhi
# 128             1         New Delhi
# 129             1         New Delhi
# 130             1         New Delhi
# 131             1         New Delhi
# 132             1         New Delhi
# 133             1         New Delhi
# 134             1         New Delhi
# 135             1         New Delhi
# 136             1         New Delhi
# 137             1         New Delhi
# 138             1         New Delhi
# 139             1         New Delhi
# 140             1         New Delhi
# 141             1         New Delhi
# 142             1         New Delhi
# 143           191           Colombo
# 144           191           Colombo
# 145             1         New Delhi
# 146             1         New Delhi
# 147             1             Noida
# 148             1           Gurgaon
# 149             1         New Delhi
# 150             1         New Delhi
# 151             1         New Delhi
# 152             1         New Delhi
# 153             1         New Delhi
# 154             1             Noida
# 155             1              Agra
# 156             1              Agra
# 157             1         Ghaziabad
# 158             1           Gurgaon
# 159             1           Gurgaon
# 160             1           Gurgaon
# 161             1           Gurgaon
# 162             1           Gurgaon
# 163             1           Gurgaon
# 164             1           Gurgaon
# 165             1           Gurgaon
# 166             1           Gurgaon
# 167             1           Gurgaon
# 168             1           Gurgaon
# 169             1           Gurgaon
# 170             1           Gurgaon
# 171             1           Gurgaon
# 172             1           Gurgaon
# 173             1            Jaipur
# 174             1         New Delhi
# 175             1         New Delhi
# 176             1         New Delhi
# 177             1         New Delhi
# 178             1         New Delhi
# 179             1         New Delhi
# 180             1         New Delhi
# 181             1         New Delhi
# 182             1         New Delhi
# 183             1         New Delhi
# 184             1         New Delhi
# 185             1         New Delhi
# 186             1         New Delhi
# 187             1         New Delhi
# 188             1         New Delhi
# 189             1         New Delhi
# 190             1         New Delhi
# 191             1         New Delhi
# 192             1         New Delhi
# 193             1         New Delhi
# 194             1         New Delhi
# 195             1         New Delhi
# 196             1         New Delhi
# 197             1         New Delhi
# 198             1         New Delhi
# 199             1         New Delhi
# 200             1         New Delhi
# 201             1         New Delhi
# 202             1         New Delhi
# 203             1         New Delhi
# 204             1             Noida
# 205             1             Noida
# 206           191           Colombo
# 207           191           Colombo
# 208           191           Colombo
# 209             1         Bangalore
# 210             1           Gurgaon
# 211             1         New Delhi
# 212             1         New Delhi
# 213             1         New Delhi
# 214             1         New Delhi
# 215             1             Noida
# 216           191           Colombo
# 217             1             Noida
# 218             1           Gurgaon
# 219             1            Jaipur
# 220             1         New Delhi
# 221             1        Chandigarh
# 222             1           Gurgaon
# 223             1           Gurgaon
# 224             1           Gurgaon
# 225             1           Gurgaon
# 226             1           Gurgaon
# 227             1         New Delhi
# 228             1         New Delhi
# 229             1         New Delhi
# 230             1         New Delhi
# 231             1         New Delhi
# 232             1         New Delhi
# 233             1         New Delhi
# 234             1         New Delhi
# 235             1         New Delhi
# 236             1         New Delhi
# 237             1         New Delhi
# 238             1         New Delhi
# 239             1         New Delhi
# 240             1         New Delhi
# 241             1         New Delhi
# 242             1         New Delhi
# 243             1         New Delhi
# 244             1         New Delhi
# 245             1             Noida
# 246             1             Noida
# 247             1             Noida
# 248             1           Gurgaon
# 249             1           Gurgaon
# 250             1         New Delhi
# 251             1         New Delhi
# 252             1         New Delhi
# 253             1         New Delhi
# 254             1         New Delhi
# 255             1         New Delhi
# 256             1         New Delhi
# 257             1              Pune
# 258           162        Pasay City
# 259           162        Pasay City
# 260             1              Agra
# 261             1         Bangalore
# 262             1           Chennai
# 263             1               Goa
# 264             1               Goa
# 265             1           Gurgaon
# 266             1           Gurgaon
# 267             1           Gurgaon
# 268             1           Gurgaon
# 269             1           Gurgaon
# 270             1           Gurgaon
# 271             1           Gurgaon
# 272             1           Gurgaon
# 273             1           Gurgaon
# 274             1           Gurgaon
# 275             1           Gurgaon
# 276             1           Gurgaon
# 277             1           Gurgaon
# 278             1           Gurgaon
# 279             1           Gurgaon
# 280             1           Gurgaon
# 281             1           Gurgaon
# 282             1           Gurgaon
# 283             1           Gurgaon
# 284             1           Gurgaon
# 285             1           Gurgaon
# 286             1           Gurgaon
# 287             1           Gurgaon
# 288             1         Hyderabad
# 289             1            Indore
# 290             1            Jaipur
# ...
# 269            4               4.0        Green   Very Good   1840
# 270            4               4.0        Green   Very Good   1658
# 271            4               3.9       Yellow        Good    490
# 272            4               3.4       Orange     Average     52
# 273            4               2.6       Orange     Average     35
# 274            4               4.0        Green   Very Good    111
# 275            4               4.6   Dark Green   Excellent   2093
# 276            4               3.9       Yellow        Good    280
# 277            4               3.7       Yellow        Good     45
# 278            4               3.2       Orange     Average    137
# 279            4               3.8       Yellow        Good    283
# 280            4               4.1        Green   Very Good   2806
# 281            4               3.0       Orange     Average     21
# 282            4               3.9       Yellow        Good   1365
# 283            4               3.9       Yellow        Good     96
# 284            4               4.0        Green   Very Good    429
# 285            4               3.2       Orange     Average     52
# 286            4               3.3       Orange     Average     36
# 287            4               2.7       Orange     Average     27
# 288            4               4.4        Green   Very Good   2218
# 289            4               3.8       Yellow        Good    209
# 290            4               4.9   Dark Green   Excellent    322
# 291            4               4.2        Green   Very Good    149
# 292            4               4.3        Green   Very Good     87
# 293            4               3.2       Orange     Average     59
# 294            4               3.2       Orange     Average    455
# 295            4               3.5       Yellow        Good    706
# 296            4               4.1        Green   Very Good   1821
# 297            4               4.2        Green   Very Good    961
# 298            4               4.0        Green   Very Good    312
# 299            4               3.2       Orange     Average     12
# 300            4               3.8       Yellow        Good    354
# 301            4               2.7       Orange     Average     81
# 302            4               3.4       Orange     Average     58
# 303            4               3.8       Yellow        Good    223
# 304            4               3.8       Yellow        Good     85
# 305            4               4.6   Dark Green   Excellent    304
# 306            4               4.3        Green   Very Good     43
# 307            4               3.9       Yellow        Good   1878
# 308            4               3.4       Orange     Average    174
# 309            4               3.9       Yellow        Good    295
# 310            4               2.8       Orange     Average     19
# 311            4               3.5       Yellow        Good     14
# 312            4               3.2       Orange     Average     17
# 313            4               3.2       Orange     Average     40
# 314            4               4.1        Green   Very Good    501
# 315            4               4.5   Dark Green   Excellent    524
# 316            4               3.6       Yellow        Good   1428
# 317            4               3.8       Yellow        Good    203
# 318            4               3.9       Yellow        Good    372
# 319            4               3.8       Yellow        Good    669
# 320            4               4.0        Green   Very Good     79
# 321            4               4.2        Green   Very Good    551
# 322            4               3.3       Orange     Average     20
# 323            4               3.9       Yellow        Good     90
# 324            4               3.7       Yellow        Good    393
# 325            4               3.7       Yellow        Good    131
# 326            4               2.7       Orange     Average     17
# 327            4               3.1       Orange     Average     80
# 328            4               3.4       Orange     Average    220
# 329            4               0.0        White   Not rated      2
# 330            4               0.0        White   Not rated      0
# 331            4               0.0        White   Not rated      1
# 332            4               3.8       Yellow        Good    601
# 333            4               2.6       Orange     Average     67
# 334            4               3.0       Orange     Average     32
# 335            4               3.1       Orange     Average     40
# 336            4               4.6   Dark Green   Excellent   1691
# 337            4               3.8       Yellow        Good     52
# 338            4               3.8       Yellow        Good    300
# 339            4               4.3        Green   Very Good     96
# 340            4               3.8       Yellow        Good    109
# 341            4               4.0        Green   Very Good    304
# 342            4               4.7   Dark Green   Excellent    268
# 343            4               4.3        Green   Very Good    130
# 344            4               4.1        Green   Very Good     68
# 345            4               0.0        White   Not rated      3
# 346            4               3.1       Orange     Average      5
# 347            4               3.2       Orange     Average     10
# 348            4               3.6       Yellow        Good     32
# 349            4               3.7       Yellow        Good     42
# 350            4               4.3        Green   Very Good    114
# 351            4               2.4          Red        Poor    221
# 352            4               3.2       Orange     Average     27
# 353            4               3.8       Yellow        Good    240
# 354            4               0.0        White   Not rated      0
# 355            4               3.2       Orange     Average     20
# 356            4               0.0        White   Not rated      0
# 357            4               3.2       Orange     Average     32
# 358            4               3.7       Yellow        Good    770
# 359            4               2.4          Red        Poor    103
# 360            4               3.1       Orange     Average    129
# 361            4               4.2        Green   Very Good    843
# 362            4               4.3        Green   Very Good    375
# 363            4               3.4       Orange     Average     62
# 364            3               3.4       Orange     Average    118
# 365            3               3.6       Yellow        Good     83
# 366            3               2.5       Orange     Average     93
# 367            3               4.1        Green   Very Good     58
# 368            4               4.1        Green   Very Good     37
# 369            3               4.2        Green   Very Good   1971
# 370            3               3.3       Orange     Average     56
# 371            3               3.0       Orange     Average      6
# 372            3               4.3        Green   Very Good    860
# 373            3               4.4        Green   Very Good   2224
# 374            3               4.3        Green   Very Good   1129
# 375            3               3.2       Orange     Average    113
# 376            3               4.3        Green   Very Good   1327
# 377            3               3.3       Orange     Average    148
# 378            3               3.2       Orange     Average      7
# 379            3               3.4       Orange     Average    763
# 380            3               3.9       Yellow        Good   1756
# 381            3               3.8       Yellow        Good   1347
# 382            3               3.6       Yellow        Good    346
# 383            3               2.8       Orange     Average    105
# 384            3               3.8       Yellow        Good    121
# 385            3               3.8       Yellow        Good    240
# 386            3               2.8       Orange     Average     91
# 387            3               4.0        Green   Very Good    242
# 388            3               4.1        Green   Very Good   1823
# 389            4               4.5   Dark Green   Excellent    618
# 390            4               3.7       Yellow        Good   1315
# 391            4               3.4       Orange     Average     94
# 392            3               4.5   Dark Green   Excellent   5705
# 393            4               4.3        Green   Very Good    128
# 394            3               4.3        Green   Very Good    228
# 395            3               3.5       Yellow        Good     37
# 396            3               4.5   Dark Green   Excellent    407
# 397            3               3.6       Yellow        Good    313
# 398            3               4.2        Green   Very Good    205
# 399            3               3.5       Yellow        Good    259
# 400            3               2.6       Orange     Average    115
# 401            3               2.1          Red        Poor     90
# 402            3               3.2       Orange     Average     12
# 403            3               2.4          Red        Poor     53
# 404            3               3.3       Orange     Average    563
# 405            3               3.9       Yellow        Good    297
# 406            3               4.4        Green   Very Good   3569
# 407            3               4.5   Dark Green   Excellent   1262
# 408            3               4.7   Dark Green   Excellent   1932
# 409            3               4.6   Dark Green   Excellent   2553
# 410            3               4.2        Green   Very Good   1859
# 411            3               4.0        Green   Very Good    916
# 412            3               4.0        Green   Very Good    911
# 413            3               4.4        Green   Very Good     77
# 414            3               3.9       Yellow        Good    173
# 415            3               2.4          Red        Poor     92
# 416            3               2.6       Orange     Average    152
# 417            3               4.7   Dark Green   Excellent    242
# 418            3               3.9       Yellow        Good    496
# 419            3               3.9       Yellow        Good    908
# 420            3               4.0        Green   Very Good   2333
# 421            3               4.1        Green   Very Good    799
# 422            3               4.0        Green   Very Good    817
# 423            3               3.7       Yellow        Good    601
# 424            3               3.8       Yellow        Good    238
# 425            3               3.1       Orange     Average    134
# 426            3               4.0        Green   Very Good   1700
# 427            3               3.3       Orange     Average     21
# 428            3               3.7       Yellow        Good    234
# 429            3               3.8       Yellow        Good     54
# 430            3               4.2        Green   Very Good    107
# 431            3               3.4       Orange     Average     35
# 432            3               3.9       Yellow        Good    484
# 433            3               3.8       Yellow        Good    663
# 434            3               3.7       Yellow        Good    780
# 435            3               3.5       Yellow        Good    234
# 436            3               3.7       Yellow        Good   2247
# 437            3               3.8       Yellow        Good    567
# 438            3               3.7       Yellow        Good   3697
# 439            3               3.7       Yellow        Good    128
# 440            3               4.2        Green   Very Good    436
# 441            3               3.5       Yellow        Good    148
# 442            3               2.8       Orange     Average     21
# 443            3               4.2        Green   Very Good    391
# 444            3               2.9       Orange     Average     48
# 445            3               3.4       Orange     Average    148
# 446            3               3.6       Yellow        Good     47
# 447            3               4.2        Green   Very Good    420
# 448            3               4.1        Green   Very Good    695
# 449            3               3.5       Yellow        Good    385
# 450            3               4.0        Green   Very Good    169
# 451            3               3.9       Yellow        Good    749
# 452            3               3.4       Orange     Average    299
# 453            3               3.7       Yellow        Good    743
# 454            3               4.3        Green   Very Good   1531
# 455            3               4.5   Dark Green   Excellent   1439
# 456            2               2.4          Red        Poor    240
# 457            3               4.1        Green   Very Good    353
# 458            3               4.1        Green   Very Good    711
# 459            3               3.2       Orange     Average     17
# 460            3               4.8   Dark Green   Excellent   1262
# 461            3               3.9       Yellow        Good    231
# 462            3               3.7       Yellow        Good    127
# 463            3               3.8       Yellow        Good    706
# 464            3               3.7       Yellow        Good    173
# 465            3               3.4       Orange     Average    294
# 466            3               3.9       Yellow        Good     67
# 467            3               3.9       Yellow        Good     81
# 468            4               3.8       Yellow        Good    162
# 469            3               3.3       Orange     Average     60
# 470            3               3.9       Yellow        Good   2003
# 471            3               3.8       Yellow        Good   1158
# 472            3               3.5       Yellow        Good    422
# 473            3               4.1        Green   Very Good    242
# 474            3               3.8       Yellow        Good    244
# 475            3               3.4       Orange     Average    267
# 476            3               3.3       Orange     Average    339
# 477            3               4.0        Green   Very Good    969
# 478            3               3.7       Yellow        Good    395
# 479            3               3.6       Yellow        Good    505
# 480            3               3.7       Yellow        Good    774
# 481            3               4.2        Green   Very Good    113
# 482            3               3.8       Yellow        Good    337
# 483            3               3.9       Yellow        Good     88
# 484            3               3.5       Yellow        Good    313
# 485            3               4.1        Green   Very Good    416
# 486            3               3.6       Yellow        Good    350
# 487            3               3.7       Yellow        Good     76
# 488            3               3.3       Orange     Average     61
# 489            3               4.5   Dark Green   Excellent   2847
# 490            4               4.1        Green   Very Good    125
# 491            4               4.4        Green   Very Good    222
# 492            3               3.9       Yellow        Good    676
# 493            3               2.9       Orange     Average     10
# 494            3               4.0        Green   Very Good    460
# 495            3               3.8       Yellow        Good     42
# 496            3               4.0        Green   Very Good   1093
# 497            3               4.0        Green   Very Good    537
# 498            3               3.8       Yellow        Good    316
# 499            3               4.2        Green   Very Good    676

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9550 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Price range           9551 non-null   int64
#  15  Aggregate rating      9551 non-null   float64
#  16  Rating color          9551 non-null   object
#  17  Rating text           9551 non-null   object
#  18  Votes                 9551 non-null   int64
# dtypes: float64(3), int64(5), object(11)
# memory usage: 1.4+ MB

# %%
#Removing column heading spaces
data.columns = data.columns.str.replace(' ', '_')

# %%
data.head()
# Out:
#    Restaurant_ID              Restaurant_Name  Country_Code     City  \
# 0        7402935                         Skye            94  Jakarta
# 1        7410290     Satoo - Hotel Shangri-La            94  Jakarta
# 2        7420899                   Sushi Masa            94  Jakarta
# 3        7421967               3 Wise Monkeys            94  Jakarta
# 4        7422489  Avec Moi Restaurant and Bar            94  Jakarta
#
#                                              Address  \
# 0  Menara BCA, Lantai 56, Jl. MH. Thamrin, Thamri...
# 1               Hotel Shangri-La, Jl. Jend. Sudirman
# 2                   Jl. Tuna Raya No. 5, Penjaringan
# 3                Jl. Suryo No. 26, Senopati, Jakarta
# 4  Gedung PIC, Jl. Teluk Betung 43, Thamrin, Jakarta
#
#                         Locality                        Locality_Verbose  \
# 0  Grand Indonesia Mall, Thamrin  Grand Indonesia Mall, Thamrin, Jakarta
# 1     Hotel Shangri-La, Sudirman     Hotel Shangri-La, Sudirman, Jakarta
# 2                    Penjaringan                    Penjaringan, Jakarta
# 3                       Senopati                       Senopati, Jakarta
# 4                        Thamrin                        Thamrin, Jakarta
#
#     Longitude  Latitude                    Cuisines  Average_Cost_for_two  \
# 0  106.821999 -6.196778        Italian, Continental                800000
# 1  106.818961 -6.203292  Asian, Indonesian, Western                800000
# 2  106.800144 -6.101298             Sushi, Japanese                500000
# 3  106.813400 -6.235241                    Japanese                450000
# 4  106.821023 -6.196270             French, Western                350000
#
#                  Currency Has_Table_booking Has_Online_delivery  Price_range  \
# 0  Indonesian Rupiah(IDR)                No                  No            3
# 1  Indonesian Rupiah(IDR)                No                  No            3
# 2  Indonesian Rupiah(IDR)                No                  No            3
# 3  Indonesian Rupiah(IDR)                No                  No            3
# 4  Indonesian Rupiah(IDR)                No                  No            3
#
#    Aggregate_rating Rating_color Rating_text  Votes
# 0               4.1        Green   Very Good   1498
# 1               4.6   Dark Green   Excellent    873
# 2               4.9   Dark Green   Excellent    605
# 3               4.2        Green   Very Good    395
# 4               4.3        Green   Very Good    243

# %% [markdown]
# ### Checking for the empty values(0) and then suming them up

# %%
(data== 0).sum()
# Out:
# Restaurant_ID              0
# Restaurant_Name            0
# Country_Code               0
# City                       0
# Address                    0
# Locality                   0
# Locality_Verbose           0
# Longitude                498
# Latitude                 498
# Cuisines                   0
# Average_Cost_for_two      18
# Currency                   0
# Has_Table_booking          0
# Has_Online_delivery        0
# Price_range                0
# Aggregate_rating        2148
# Rating_color               0
# Rating_text                0
# Votes                   1094
# dtype: int64

# %% [markdown]
# ### Dealing with missing data in Latitude and Longitude

# %%
missing_city = data[(data.Longitude == 0)| (data.Latitude == 0)].City.unique()

len(missing_city)
# Out:
# 28

# %% [markdown]
# ### Filling the Missing Latitude and Longitude

# %%
# Calculate the mean Latitude and Longitude for each City, filter for missing cities
lat_n_long = data.groupby('City').agg({"Latitude":"mean", "Longitude":"mean"}).loc[missing_city]

# Create a dictionary with missing city locations
missing_city_loc = {x: tuple(lat_n_long.loc[x]) for x in missing_city}

# Count the number of rows where Latitude or Longitude is 0
missing_coords_count = ((data.Latitude == 0) | (data.Longitude == 0)).sum()

missing_coords_count
# Out:
# 499

# %%
len(lat_n_long)
# Out:
# 28

# %% [markdown]
# In essence, this code loops through each row in the DataFrame data. If it encounters a row where either the latitude or longitude value is zero, it replaces those zero values with estimated coordinates retrieved from the missing_city_loc dictionary based on the city associated with that row. This operation aims to update missing or zero coordinates with estimated values for the respective cities in the dataset.

# %%
for i in data.index:
    if(data.loc[i,'Latitude'] == 0) or (data.loc[i, 'Longitude'] == 0):
        city = data.loc[i, 'City']
        lat, long = missing_city_loc[city]
        data.loc[i, 'Longitude'] = long
        data.loc[i, 'Latitude'] = lat

# %% [markdown]
# ### Dealing with duplicates

# %%
print('Any Duplicated Rows ? :', data.duplicated().any())
print('No. of Duplicated Rows :', data.duplicated().sum())
# Out:
# Any Duplicated Rows ? : False
# No. of Duplicated Rows : 0

# %%
data.duplicated('Restaurant_ID').any()
# Out:
# False

# %%
print('No. of unique Restaurant_IDs :', data.Restaurant_ID.nunique())
print('No. of unique Restaurant_Names:', data.Restaurant_Name.nunique())
# Out:
# No. of unique Restaurant_IDs : 9551
# No. of unique Restaurant_Names: 7445

# %% [markdown]
# ### Explore the geographical distribution of the restaurants and identify the cities with the maximum and minimum number of restaurants

# %%
country_code = pd.read_excel('/Users/parvezshahshaik/Documents/Github/restaurant_recommendation/restaurent_data/Country-Code.xlsx')

country_code.columns = country_code.columns.str.replace(' ','_')

country_code
# Out:
#     Country_Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %%
data = pd.merge(data, country_code, on = 'Country_Code')

data.head()
# Out:
#    Restaurant_ID              Restaurant_Name  Country_Code     City  \
# 0        7402935                         Skye            94  Jakarta
# 1        7410290     Satoo - Hotel Shangri-La            94  Jakarta
# 2        7420899                   Sushi Masa            94  Jakarta
# 3        7421967               3 Wise Monkeys            94  Jakarta
# 4        7422489  Avec Moi Restaurant and Bar            94  Jakarta
#
#                                              Address  \
# 0  Menara BCA, Lantai 56, Jl. MH. Thamrin, Thamri...
# 1               Hotel Shangri-La, Jl. Jend. Sudirman
# 2                   Jl. Tuna Raya No. 5, Penjaringan
# 3                Jl. Suryo No. 26, Senopati, Jakarta
# 4  Gedung PIC, Jl. Teluk Betung 43, Thamrin, Jakarta
#
#                         Locality                        Locality_Verbose  \
# 0  Grand Indonesia Mall, Thamrin  Grand Indonesia Mall, Thamrin, Jakarta
# 1     Hotel Shangri-La, Sudirman     Hotel Shangri-La, Sudirman, Jakarta
# 2                    Penjaringan                    Penjaringan, Jakarta
# 3                       Senopati                       Senopati, Jakarta
# 4                        Thamrin                        Thamrin, Jakarta
#
#     Longitude  Latitude                    Cuisines  Average_Cost_for_two  \
# 0  106.821999 -6.196778        Italian, Continental                800000
# 1  106.818961 -6.203292  Asian, Indonesian, Western                800000
# 2  106.800144 -6.101298             Sushi, Japanese                500000
# 3  106.813400 -6.235241                    Japanese                450000
# 4  106.821023 -6.196270             French, Western                350000
#
#                  Currency Has_Table_booking Has_Online_delivery  Price_range  \
# 0  Indonesian Rupiah(IDR)                No                  No            3
# 1  Indonesian Rupiah(IDR)                No                  No            3
# 2  Indonesian Rupiah(IDR)                No                  No            3
# 3  Indonesian Rupiah(IDR)                No                  No            3
# 4  Indonesian Rupiah(IDR)                No                  No            3
#
#    Aggregate_rating Rating_color Rating_text  Votes    Country
# 0               4.1        Green   Very Good   1498  Indonesia
# 1               4.6   Dark Green   Excellent    873  Indonesia
# 2               4.9   Dark Green   Excellent    605  Indonesia
# 3               4.2        Green   Very Good    395  Indonesia
# 4               4.3        Green   Very Good    243  Indonesia

# %% [markdown]
# ### Finding out the cities with maximun and minimum restaurants

# %% [markdown]
# The .value_counts() method in Pandas is used to count the occurrences of unique values in a Series (a single column of a DataFrame). It returns a new Series containing counts of unique values in descending order.

# %%
vc = data['Country'].value_counts().reset_index()
vc.columns = ['Country', 'Freq']
vc
# Out:
#            Country  Freq
# 0            India  8652
# 1    United States   434
# 2   United Kingdom    80
# 3     South Africa    60
# 4              UAE    60
# 5           Brazil    60
# 6      New Zealand    40
# 7           Turkey    34
# 8        Australia    24
# 9      Phillipines    22
# 10       Indonesia    21
# 11       Sri Lanka    20
# 12           Qatar    20
# 13       Singapore    20
# 14          Canada     4

# %%
#Calculating the Perc
vc['Perc'] = (vc['Freq'] / vc['Freq'].sum() * 100).round(1)
vc['Perc']
# Out:
# 0     90.6
# 1      4.5
# 2      0.8
# 3      0.6
# 4      0.6
# 5      0.6
# 6      0.4
# 7      0.4
# 8      0.3
# 9      0.2
# 10     0.2
# 11     0.2
# 12     0.2
# 13     0.2
# 14     0.0
# Name: Perc, dtype: float64

# %% [markdown]
# When Seaborn's countplot() function is called with x='Country', it automatically counts the occurrences of each unique country in the 'Country' column and represents those counts on the y-axis of the plot. The resulting plot displays bars corresponding to each country's count, making it a countplot that visualizes the distribution of occurrences of each country in the dataset.

# %%
#Plotting the data
plt.figure(figsize = (20,5))

sns.countplot( x='Country', data=data, order=vc['Country'])

for i, row in vc.iterrows():
    plt.annotate(
                  str(row['Perc']) + '%', 
                  xy=(i, row['Freq']/2), 
                  ha='center', 
                  fontsize=12
                 )
plt.xticks(rotation=45, ha='right', size=12)
plt.xlabel('Country',size=16)
plt.show();

# %%
vc = pd.Series()
vc['India'] = len(data[data.Country == 'India'])
vc['Other'] = len(data[data.Country != 'India'])
vc.plot.pie(
    radius = 2,
    autopct = '%1.1f%%',
    textprops = {'size': 15},
    explode = [0.1,0.1],
    shadow = True,
    cmap = 'Set2'
)

plt.xticks(size = 12, rotation = 10)
plt.ylabel('')
plt.show()

# %% [markdown]
# India has the largest market of restaurants and no other countries even come close to it

# %%
#Displays onlys data from India
data = data[data.Country == 'India']
data.head()
# Out:
#     Restaurant_ID                             Restaurant_Name  Country_Code  \
# 21           2701           Orient Express - Taj Palace Hotel             1
# 22         309548    Tian - Asian Cuisine Studio - ITC Maurya             1
# 23           2742                        Bukhara - ITC Maurya             1
# 24         301523  Nostalgia at 1911 Brasserie - The Imperial             1
# 25           2724                         1911 - The Imperial             1
#
#          City                                            Address  \
# 21  New Delhi  Taj Palace Hotel, Diplomatic Enclave, Chanakya...
# 22  New Delhi  ITC Maurya, Diplomatic Enclave, Chanakyapuri, ...
# 23  New Delhi                ITC Maurya, Chanakyapuri, New Delhi
# 24  New Delhi                   The Imperial, Janpath, New Delhi
# 25  New Delhi                   The Imperial, Janpath, New Delhi
#
#                               Locality  \
# 21  The Taj Palace Hotel, Chanakyapuri
# 22            ITC Maurya, Chanakyapuri
# 23            ITC Maurya, Chanakyapuri
# 24               The Imperial, Janpath
# 25               The Imperial, Janpath
#
#                                  Locality_Verbose  Longitude   Latitude  \
# 21  The Taj Palace Hotel, Chanakyapuri, New Delhi  77.170087  28.595008
# 22            ITC Maurya, Chanakyapuri, New Delhi  77.173455  28.597351
# 23            ITC Maurya, Chanakyapuri, New Delhi  77.173724  28.597466
# 24               The Imperial, Janpath, New Delhi  77.218187  28.625445
# 25               The Imperial, Janpath, New Delhi  77.218185  28.625443
#
#                                         Cuisines  Average_Cost_for_two  \
# 21                                      European                  8000
# 22        Asian, Japanese, Korean, Thai, Chinese                  7000
# 23                                  North Indian                  6500
# 24                         European, Continental                  6000
# 25  North Indian, Chinese, South Indian, Italian                  6000
#
#               Currency Has_Table_booking Has_Online_delivery  Price_range  \
# 21  Indian Rupees(Rs.)               Yes                  No            4
# 22  Indian Rupees(Rs.)                No                  No            4
# 23  Indian Rupees(Rs.)                No                  No            4
# 24  Indian Rupees(Rs.)               Yes                  No            4
# 25  Indian Rupees(Rs.)               Yes                  No            4
#
#     Aggregate_rating Rating_color Rating_text  Votes Country
# 21               4.0        Green   Very Good    145   India
# 22               4.1        Green   Very Good    188   India
# 23               4.4        Green   Very Good   2826   India
# 24               3.2       Orange     Average     12   India
# 25               3.9       Yellow        Good    272   India

# %% [markdown]
# ### Exploring how ratings are distributed overall to Restaurants

# %%
data['Rating_cat'] = data['Aggregate_rating'].round(0).astype(int)
data.head()
# Out:
#     Restaurant_ID                             Restaurant_Name  Country_Code  \
# 21           2701           Orient Express - Taj Palace Hotel             1
# 22         309548    Tian - Asian Cuisine Studio - ITC Maurya             1
# 23           2742                        Bukhara - ITC Maurya             1
# 24         301523  Nostalgia at 1911 Brasserie - The Imperial             1
# 25           2724                         1911 - The Imperial             1
#
#          City                                            Address  \
# 21  New Delhi  Taj Palace Hotel, Diplomatic Enclave, Chanakya...
# 22  New Delhi  ITC Maurya, Diplomatic Enclave, Chanakyapuri, ...
# 23  New Delhi                ITC Maurya, Chanakyapuri, New Delhi
# 24  New Delhi                   The Imperial, Janpath, New Delhi
# 25  New Delhi                   The Imperial, Janpath, New Delhi
#
#                               Locality  \
# 21  The Taj Palace Hotel, Chanakyapuri
# 22            ITC Maurya, Chanakyapuri
# 23            ITC Maurya, Chanakyapuri
# 24               The Imperial, Janpath
# 25               The Imperial, Janpath
#
#                                  Locality_Verbose  Longitude   Latitude  \
# 21  The Taj Palace Hotel, Chanakyapuri, New Delhi  77.170087  28.595008
# 22            ITC Maurya, Chanakyapuri, New Delhi  77.173455  28.597351
# 23            ITC Maurya, Chanakyapuri, New Delhi  77.173724  28.597466
# 24               The Imperial, Janpath, New Delhi  77.218187  28.625445
# 25               The Imperial, Janpath, New Delhi  77.218185  28.625443
#
#                                         Cuisines  Average_Cost_for_two  \
# 21                                      European                  8000
# 22        Asian, Japanese, Korean, Thai, Chinese                  7000
# 23                                  North Indian                  6500
# 24                         European, Continental                  6000
# 25  North Indian, Chinese, South Indian, Italian                  6000
#
#               Currency Has_Table_booking Has_Online_delivery  Price_range  \
# 21  Indian Rupees(Rs.)               Yes                  No            4
# 22  Indian Rupees(Rs.)                No                  No            4
# 23  Indian Rupees(Rs.)                No                  No            4
# 24  Indian Rupees(Rs.)               Yes                  No            4
# 25  Indian Rupees(Rs.)               Yes                  No            4
#
#     Aggregate_rating Rating_color Rating_text  Votes Country  Rating_cat
# 21               4.0        Green   Very Good    145   India           4
# 22               4.1        Green   Very Good    188   India           4
# 23               4.4        Green   Very Good   2826   India           4
# 24               3.2       Orange     Average     12   India           3
# 25               3.9       Yellow        Good    272   India           4

# %%
#Plotting the chart
plt.figure(figsize = (15, 4))

sns.countplot(
    x = 'Aggregate_rating',
    data = data[data['Aggregate_rating'] != 0],
    palette = 'magma'
)

plt.xticks(rotation=70)
plt.title('Y')
plt.ylabel('Count of Restaurants')
plt.show();

# %% [markdown]
# ### Effect of color on Rating

# %%
data["Rating_color"].value_counts()

Color_represents = data.groupby(['Rating_color'], as_index = False)['Aggregate_rating'].mean()

Color_represents
# Out:
#   Rating_color  Aggregate_rating
# 0   Dark Green          4.646552
# 1        Green          4.153324
# 2       Orange          3.048722
# 3          Red          2.296111
# 4        White          0.000000
# 5       Yellow          3.677423

# %%
Color_represents.columns = ['Rating_color', 'Average_rating']

Color_represents
# Out:
#   Rating_color  Average_rating
# 0   Dark Green        4.646552
# 1        Green        4.153324
# 5       Yellow        3.677423
# 2       Orange        3.048722
# 3          Red        2.296111
# 4        White        0.000000

# %%
Color_represents = Color_represents.sort_values(by = 'Average_rating', ascending=False)

Color_represents
# Out:
#   Rating_color  Average_rating
# 0   Dark Green        4.646552
# 1        Green        4.153324
# 5       Yellow        3.677423
# 2       Orange        3.048722
# 3          Red        2.296111
# 4        White        0.000000

# %%
Color_represents = Color_represents[0:5]

Color_represents['Rating'] = ['Excellent', 'Very Good', 'Good', 'Okay', 'Poor']

Color_represents
# Out:
#   Rating_color  Average_rating     Rating
# 0   Dark Green        4.646552  Excellent
# 1        Green        4.153324  Very Good
# 5       Yellow        3.677423       Good
# 2       Orange        3.048722       Okay
# 3          Red        2.296111       Poor

# %% [markdown]
# ### Plotting a Bar Chart between Top 5 restaurants vs Count

# %% [markdown]
# The bar plot illustrates the count of restaurants in the top five cities, where each bar's height represents the number of restaurants in a particular city. The x-axis displays the city names, and the y-axis represents the count of restaurants in each city.

# %%
plt.figure(figsize=(15, 5))

vc = data['City'].value_counts()[:5]

g = sns.barplot(
    x = vc.index,
    y = vc.values,
    palette='Set2'
)

for i in range(5):
    value = vc[i]
    g.text(y = value -2, x = i+0.125, s = value, color = 'black', ha = 'center', fontsize=15)

g.set_xticklabels(g.get_xticklabels(), fontsize=13)
g.set_ylabel('Count', fontsize = 15)
g.set_title('Restaurant presence', fontsize = 30, color='darkred')

plt.show()

# %% [markdown]
# This visualization offers a quick and engaging way to observe which restaurant names occur most frequently, potentially highlighting popular or commonly encountered restaurant names within the dataset.

# %%
from wordcloud import WordCloud, STOPWORDS

stopwords = set(STOPWORDS)
wordcloud = (WordCloud(
    width = 1440, 
    height = 1080, 
    relative_scaling = 0.5,
    stopwords=stopwords).generate_from_frequencies(data['Restaurant_Name'].value_counts())
    )

fig = plt.figure(1, figsize = (15, 15))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %% [markdown]
# ### Horizontal bar plot showcasing the top 10 most frequent restaurant names

# %%
plt.figure(figsize=(15, 10))

vc = data['Restaurant_Name'].value_counts()[:10]

g = sns.barplot(y=vc.index, x=vc.values, palette='Set2')
g.set_yticklabels(g.get_yticklabels(), fontsize=13)

for i in range(10):
    value = vc[i]
    g.text(x=value - 2, y=i + 0.125, s=value, color='black', ha="center", fontsize=15)

g.set_xlabel('Count', fontsize=15)
g.set_title('c', fontsize=30, color='darkred')

plt.show()

# %% [markdown]
# ### Donut Chart 1: Restaurants that allow table booking vs that do not allow table booking
#
# ### Donut Chart 2: Restaurants that provide online delivery vs Restaurants that dont

# %%
f, axes = plt.subplots(1, 2, figsize=(20, 7))

# Restaurants that allow table booking vs that dont
data['Has_Table_booking'].value_counts().plot.pie(
                                                ax=axes[0], 
                                                autopct='%0.1f%%', 
                                                radius=1.25,
                                                wedgeprops={'width': 0.75}, 
                                                cmap='Set2',
                                                textprops={'size': 18})

axes[0].set_title('Table Booking\n', fontsize=16)
axes[0].set_ylabel('')

#Restaurants that has online delivery vs that dont
data['Has_Online_delivery'].value_counts().plot.pie(
                                                ax=axes[1], 
                                                autopct='%0.1f%%', 
                                                radius=1.25,
                                                wedgeprops={'width': 0.75}, 
                                                cmap='Set2_r',
                                                textprops={'size': 18})

axes[1].set_title('Online Delivery\n', fontsize=16)
axes[1].set_ylabel('')

plt.tight_layout(w_pad=20, h_pad=10, pad=4)
plt.show()

# %%
pd.crosstab(data.Has_Online_delivery,data.Has_Table_booking)
# Out:
# Has_Table_booking      No  Yes
# Has_Online_delivery
# No                   5545  684
# Yes                  1996  427

# %% [markdown]
# ## The set of visualizations aims to offer insights into the relationship between online delivery and table booking services among restaurants in the dataset.
#
# ### Venn Diagram (Left):
# * Illustrates the overlap and differences between restaurants that offer online delivery and those that provide table booking services.
# * The overlapping region represents restaurants that offer both services.
# * The unique sections show restaurants that provide only online delivery, only table booking, or neither service.
# * Helps understand the distribution and intersection of restaurants based on their service offerings.
#
# ### Bar Plot (Right):
# * Displays the total number of votes received by different categories of restaurants categorized by their service offerings (Online Delivery and Table Booking).
# * The x-axis shows four categories: 'None' (neither service), 'Only Table Booking', 'Only Delivery', and 'Both' services.
# * The y-axis represents the total number of votes received by restaurants falling into each category.
# * Annotations on the bars display the percentage of votes relative to the total votes in each category.

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 5))

s1 = set(data[data['Has_Online_delivery'] == 'Yes']['Restaurant_ID'])
s2 = set(data[data['Has_Table_booking'] == 'Yes']['Restaurant_ID'])
out = venn2(
    [s1, s2], 
    ['Online Delivery', 'Table Booking'], 
    ['salmon', 'seagreen'], 
    alpha = 0.91,
    ax = ax[0]
    )

dc = data.pivot_table(index=['Has_Online_delivery', 'Has_Table_booking'], values='Votes', aggfunc='sum')
dc.index = ['None', 'Only Table Booking', 'Only Delivery', 'Both']
dc['Perc'] = (dc['Votes'] / dc['Votes'].sum() * 100).round(2)

sns.barplot(x=dc.index, y=dc['Votes'], ax=ax[1])
plt.xticks(rotation=0, fontsize=14)
plt.xlabel('')

for i in range(len(dc)):
    plt.annotate(str(dc['Perc'].iloc[i]) + '%', xy=(i - 0.15, int(dc['Votes'].iloc[i] / 2)), fontsize=12)

plt.ylabel('No. of Votes', fontsize=20)
plt.show()

# %%
dc
# Out:
#                      Votes   Perc
# None                496366  41.81
# Only Table Booking  184183  15.51
# Only Delivery       305369  25.72
# Both                201245  16.95

# %% [markdown]
# The crossplot representation helps to compare the presence or absence of online delivery services across different aggregate rating levels. It indicates the distribution of restaurants with respect to their aggregate ratings and their online delivery availability.

# %%
d = data[data.Aggregate_rating != 0]
pd.crosstab(d.Aggregate_rating, d.Has_Online_delivery).plot.bar();

# %%
plt.figure(figsize=(20,6))

sns.countplot(
    data=data[data.Aggregate_rating !=0],
    x='Aggregate_rating',
    hue='Has_Online_delivery',
    palette='viridis')

plt.show()

# %% [markdown]
# ### Restaurants across city

# %%
top10 = data.City.value_counts()[:10]

top10[:2]
# Out:
# City
# New Delhi    5473
# Gurgaon      1118
# Name: count, dtype: int64

# %% [markdown]
# ### Top 10 Cuisines served across the city

# %%
l = []

for i in data['Cuisines'].str.split(','):
    l.extend(i)

s = pd.Series([i.strip() for i in l])

stopwords = set(STOPWORDS)
wordcloud = WordCloud(stopwords=stopwords).generate_from_frequencies(s.value_counts())

fig = plt.figure(1, figsize=(15, 15))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %% [markdown]
# ### Visualization of Top 10 Cuisines

# %%
plt.figure(figsize=(15, 5))

sns.barplot(
    x=s.value_counts()[:10].index, 
    y=s.value_counts()[:10])

for i in range(10):
    plt.annotate(s.value_counts()[i], 
                 xy=(i - 0.15, 
                     s.value_counts()[i] + 50), 
                     fontsize=14)

plt.ylim(0, round(s.value_counts()[0] + 300))

plt.show()

# %%
data['no_cuisines'] = data.Cuisines.str.split(',').apply(len)

# %% [markdown]
# ### This Bar chart visualizes the distribution of restaurants based on the number of cuisines they offer.

# %%
plt.figure(figsize=(15, 5))
vc = data['no_cuisines'].value_counts() 
sns.countplot(x='no_cuisines', data=data, order=vc.index)

for i in range(len(vc)):
    plt.annotate(vc.iloc[i], xy=(i - 0.07, vc.iloc[i] + 10), fontsize=12)

plt.show()

# %% [markdown]
# ### No. of cuisines vs rating

# %%
 data.columns
# Out:
# Index(['Restaurant_ID', 'Restaurant_Name', 'Country_Code', 'City', 'Address',
#        'Locality', 'Locality_Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average_Cost_for_two', 'Currency', 'Has_Table_booking',
#        'Has_Online_delivery', 'Price_range', 'Aggregate_rating',
#        'Rating_color', 'Rating_text', 'Votes', 'Country', 'Rating_cat',
#        'no_cuisines'],
#       dtype='object')

# %%
plt.figure(figsize=(20, 5))

fusion_rate = data.loc[data['Aggregate_rating'] > 0, ['no_cuisines', 'Aggregate_rating']].copy()
fusion_rate.loc[fusion_rate['no_cuisines'] > 5, 'no_cuisines'] = 5
fusion_rate = fusion_rate.loc[fusion_rate['Aggregate_rating'] != -1, :]

pal = sns.color_palette('Oranges', 11)

for i in range(1, 6):
    num_ix = fusion_rate['no_cuisines'] == i
    sns.distplot(fusion_rate.loc[num_ix, 'Aggregate_rating'], label=str(i), hist=False)

plt.legend()
plt.title('Cuisine Rating Distribution')
plt.xlabel('Aggregate Rating')
plt.ylabel('Density')
plt.show()

# %%
plt.figure(figsize = (15,5))

sns.distplot(
    data[data.Average_Cost_for_two != 0].Average_Cost_for_two)

plt.show()

# %% [markdown]
# ### Factors in the data that may have an effect on ratings e.g. No. of cuisines, cost, delivery option etc.

# %%
data['Average_Cost_for_two_cat']= pd.cut(data[data.Average_Cost_for_two != 0].Average_Cost_for_two,
       bins = [0, 200, 500, 1000, 3000, 5000,10000, 800000000],
                                         
labels = ['<=200', '<=500', '<=1000', '<=3000', '<=5000', '<=10000', 'no␣ ,→limit'])

# %%
# Check the existence of columns and their values
print(data.columns)  # Check if 'Average_Cost_for_two_cat' and 'Price_range' are present

# Print unique values in 'Average_Cost_for_two_cat' and 'Price_range' columns
print(data['Average_Cost_for_two_cat'].unique())
print(data['Price_range'].unique())
# Out:
# Index(['Restaurant_ID', 'Restaurant_Name', 'Country_Code', 'City', 'Address',
#        'Locality', 'Locality_Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average_Cost_for_two', 'Currency', 'Has_Table_booking',
#        'Has_Online_delivery', 'Price_range', 'Aggregate_rating',
#        'Rating_color', 'Rating_text', 'Votes', 'Country', 'Rating_cat',
#        'no_cuisines', 'Average_Cost_for_two_cat'],
#       dtype='object')
# ['<=10000', '<=5000', '<=3000', '<=1000', '<=500', '<=200', NaN]
# Categories (7, object): ['<=200' < '<=500' < '<=1000' < '<=3000' < '<=5000' < '<=10000' < 'no␣ ,→limit']
# [4 3 2 1]

# %%
# Convert 'Average_Cost_for_two_cat' to a string-based column temporarily
data['Average_Cost_for_two_cat'] = data['Average_Cost_for_two_cat'].astype(str)

# Replace 'NaN' values with a valid category or 'Other'
data['Average_Cost_for_two_cat'].replace('nan', 'Other', inplace=True)

# Convert 'Average_Cost_for_two_cat' back to categorical type
data['Average_Cost_for_two_cat'] = data['Average_Cost_for_two_cat'].astype('category')

# Remove any rows containing unexpected values like 'no limit'
data = data[~data['Average_Cost_for_two_cat'].isin(['no limit'])]

# Recheck unique values after modifications
print(data['Average_Cost_for_two_cat'].unique())

# Now, try running the plotting code after ensuring the column has only valid categories.
# Use the previous plotting code after making sure the data is clean and ready for visualization.
# Out:
# ['<=10000', '<=5000', '<=3000', '<=1000', '<=500', '<=200', 'Other']
# Categories (7, object): ['<=1000', '<=10000', '<=200', '<=3000', '<=500', '<=5000', 'Other']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

f = plt.figure(figsize=(20, 10))

# First subplot: Count plot for 'Average_Cost_for_two_cat'
ax1 = plt.subplot2grid((2, 5), (0, 0), colspan=2)
sns.countplot(x='Average_Cost_for_two_cat', data=data, ax=ax1, palette=sns.color_palette('magma', 7))
ax1.set_title('Average Price')
ax1.set_xlabel('')
ax1.tick_params(axis='x', rotation=70)

# Second subplot: Boxplot for 'Aggregate_rating' vs 'Average_Cost_for_two_cat'
ax2 = plt.subplot2grid((2, 5), (0, 2), colspan=3)
sns.boxplot(x='Average_Cost_for_two_cat', y='Aggregate_rating', data=data, ax=ax2, palette=sns.color_palette('magma', 7))

# Calculate count for 'Price_range'
count = data['Price_range'].value_counts().reset_index()
count.columns = ['Price_range', 'Count']

# Third subplot: Bar plot for count of 'Price_range'
ax3 = plt.subplot2grid((2, 5), (1, 0), colspan=2)
sns.barplot(x='Price_range', y='Count', data=count, ax=ax3, palette=sns.color_palette('magma', 5))
ax3.set_title('Price Range')
ax3.set_xlabel('')

# Fourth subplot: Boxplot for 'Aggregate_rating' vs 'Price_range'
ax4 = plt.subplot2grid((2, 5), (1, 2), colspan=3)
sns.boxplot(x='Price_range', y='Aggregate_rating', data=data, ax=ax4, palette=sns.color_palette('magma', 5))

plt.subplots_adjust(wspace=0.3, hspace=0.4)
plt.suptitle('Price Count & Rating Distribution', size=30)
plt.show()

# %% [markdown]
# ### Aggregate Rating vs Vote

# %%
import matplotlib.pyplot as plt
import seaborn as sns

f, ax = plt.subplots(1, 2, figsize=(20, 6))

# Scatter plot for 'Aggregate_rating' vs 'Votes'
sns.scatterplot(data=data, x='Aggregate_rating', y='Votes', ax=ax[0], palette='Set2')
ax[0].set_ylim(0, 1000)
ax[0].set_xlim(1, 5)
ax[0].set_ylabel('Votes', fontsize=18)
ax[0].set_xlabel('Aggregate Rating', fontsize=18)
ax[0].set_xticklabels(ax[0].get_xticks(), fontsize=12)

# Bar plot for total votes in each 'Rating_cat'
agg = data.pivot_table(index='Rating_cat', values='Votes', aggfunc='sum').reset_index()
agg['Perc_votes'] = (agg['Votes'] / agg['Votes'].sum() * 100).round(2)

sns.barplot(x='Rating_cat', y='Votes', data=agg, ax=ax[1], palette='Set2')
for i in range(len(agg)):
    ax[1].annotate(str(agg['Perc_votes'][i]) + ' %', xy=(i - 0.2, int(agg['Votes'][i] / 2)),
                   fontsize=14, fontweight='medium')

ax[1].set_ylabel('Total Votes', fontsize=18)
ax[1].set_xlabel('Rating Category', fontsize=18)
ax[1].set_xticklabels(agg['Rating_cat'], fontsize=12)

plt.suptitle('Aggregate Rating Vs Votes', size=30)
plt.show()
